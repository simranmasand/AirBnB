# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_style("white")
import pandas as pd
my_dpi=96
 
# Get the data (csv file is hosted on the web)
url = 'https://python-graph-gallery.com/wp-content/uploads/gapminderData.csv'
data = pd.read_csv(url)
 
# And I need to transform my categorical column (continent) in a numerical value group1->1, group2->2...
data['continent']=pd.Categorical(data['continent'])
 
# For each year:
for i in data.year.unique():
 
# initialize a figure
    fig = plt.figure(figsize=(680/my_dpi, 480/my_dpi), dpi=my_dpi)
 
# Change color with c and alpha. I map the color to the X axis value.
    tmp=data[ data.year == i ]
    plt.scatter(tmp['lifeExp'], tmp['gdpPercap'] , s=tmp['pop']/200000 , c=tmp['continent'].cat.codes, cmap="Accent", alpha=0.6, edgecolors="white", linewidth=2);
 
# Add titles (main and on axis)
    plt.yscale('log')
    plt.xlabel("Life Expectancy")
    plt.ylabel("GDP per Capita")
    plt.title("Year: "+str(i) )
    plt.ylim(0,100000)
    plt.xlim(30, 90)
 
# Save it
    filename='Gapminder_step'+str(i)+'.png'
    plt.savefig(filename, dpi=96)
    plt.gca()
#Transformation in a GIF using Image Magick

#view sourceprint?
# Then use image magick (this is bash, not python)
#
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '

# %%
import glob
import os

gif_name = 'outputName'
file_list = glob.glob('*.png') # Get all the pngs in the current directory
#list.sort(file_list, key=lambda x: int(x.split('_')[1].split('.png')[0])) # Sort the images by #, this may need to be tweaked for your use case

with open('image_list.txt', 'w') as file:
    for item in file_list:
        file.write("%s\n" % item)

os.system('convert @image_list.txt {}.gif'.format(gif_name))
# Out:
# 4

# %%
#import glob
import moviepy.editor as mpy

gif_name = 'outputName'
fps = 12
file_list = glob.glob('*.png') # Get all the pngs in the current directory
#list.sort(file_list, key=lambda x: int(x.split('_')[1].split('.png')[0])) # Sort the images by #, this may need to be tweaked for your use case
clip = mpy.ImageSequenceClip(file_list, fps=fps)
clip.write_gif('{}.gif'.format(gif_name), fps=fps)
# Out:
# t:  17%|███████████▋                                                          | 2/12 [00:00<00:00, 17.10it/s, now=None]
# MoviePy - Building file outputName.gif with imageio.

# %%
import imageio

# %%
# !pip freeze
# Out:
# alabaster==0.7.10
# anaconda-client==1.6.14
# anaconda-navigator==1.8.7
# anaconda-project==0.8.2
# asn1crypto==0.24.0
# astroid==1.6.3
# astropy==3.0.2
# attrs==18.1.0
# Babel==2.5.3
# backcall==0.1.0
# backports.shutil-get-terminal-size==1.0.0
# beautifulsoup4==4.6.0
# bitarray==0.8.1
# bkcharts==0.2
# blaze==0.11.3
# bleach==2.1.3
# bokeh==0.12.16
# boto==2.48.0
# Bottleneck==1.2.1
# certifi==2018.4.16
# cffi==1.11.5
# chardet==3.0.4
# click==6.7
# cloudpickle==0.5.3
# clyent==1.2.2
# colorama==0.3.9
# comtypes==1.1.4
# conda==4.5.4
# conda-build==3.10.5
# conda-verify==2.0.0
# contextlib2==0.5.5
# cryptography==2.2.2
# cycler==0.10.0
# Cython==0.28.2
# cytoolz==0.9.0.1
# dask==0.17.5
# datashape==0.5.4
# decorator==4.3.0
# distributed==1.21.8
# docutils==0.14
# entrypoints==0.2.3
# et-xmlfile==1.0.1
# fastcache==1.0.2
# filelock==3.0.4
# Flask==1.0.2
# Flask-Cors==3.0.4
# gevent==1.3.0
# glob2==0.6
# greenlet==0.4.13
# h5py==2.7.1
# heapdict==1.0.0
# html5lib==1.0.1
# idna==2.6
# imageio==2.3.0
# imagesize==1.0.0
# ipykernel==4.8.2
# ipython==6.5.0
# ipython-genutils==0.2.0
# ipywidgets==7.2.1
# isort==4.3.4
# itsdangerous==0.24
# jdcal==1.4
# jedi==0.12.1
# Jinja2==2.10
# jsonschema==2.6.0
# jupyter==1.0.0
# jupyter-client==5.2.3
# jupyter-console==5.2.0
# jupyter-core==4.4.0
# jupyterlab==0.32.1
# jupyterlab-launcher==0.10.5
# kiwisolver==1.0.1
# lazy-object-proxy==1.3.1
# line-profiler==2.1.2
# llvmlite==0.23.1
# locket==0.2.0
# lxml==4.2.1
# MarkupSafe==1.0
# matplotlib==2.2.2
# mccabe==0.6.1
# menuinst==1.4.14
# mistune==0.8.3
# mkl-fft==1.0.0
# mkl-random==1.0.1
# more-itertools==4.1.0
# mpmath==1.0.0
# msgpack==0.6.2
# msgpack-python==0.5.6
# multipledispatch==0.5.0
# navigator-updater==0.2.1
# nbconvert==5.3.1
# nbformat==4.4.0
# networkx==2.1
# nltk==3.3
# nose==1.3.7
# notebook==5.5.0
# numba==0.38.0
# numexpr==2.6.5
# numpy==1.17.0
# numpydoc==0.8.0
# odo==0.5.1
# olefile==0.45.1
# openpyxl==2.5.3
# packaging==17.1
# pandas==0.25.0
# pandas-datareader==0.7.4
# pandocfilters==1.4.2
# parso==0.3.1
# partd==0.3.8
# path.py==11.0.1
# pathlib2==2.3.2
# patsy==0.5.0
# pep8==1.7.1
# pickleshare==0.7.4
# Pillow==5.1.0
# pkginfo==1.4.2
# pluggy==0.6.0
# ply==3.11
# prompt-toolkit==1.0.15
# psutil==5.4.5
# py==1.5.3
# pycodestyle==2.4.0
# pycosat==0.6.3
# pycparser==2.18
# pycrypto==2.6.1
# pycurl==7.43.0.1
# pyflakes==1.6.0
# Pygments==2.2.0
# pylint==1.8.4
# pyodbc==4.0.23
# pyOpenSSL==18.0.0
# pyparsing==2.3.1
# PySocks==1.6.8
# pytest==3.5.1
# pytest-arraydiff==0.2
# pytest-astropy==0.3.0
# pytest-doctestplus==0.1.3
# pytest-openfiles==0.3.0
# pytest-remotedata==0.2.1
# python-dateutil==2.8.0
# pytz==2018.9
# PyWavelets==0.5.2
# pywin32==223
# pywinpty==0.5.1
# PyYAML==3.12
# pyzmq==17.0.0
# QtAwesome==0.4.4
# qtconsole==4.3.1
# QtPy==1.4.1
# requests==2.18.4
# rope==0.10.7
# ruamel-yaml==0.15.35
# scikit-image==0.13.1
# scikit-learn==0.19.1
# scipy==1.3.1
# seaborn==0.8.1
# Send2Trash==1.5.0
# simplegeneric==0.8.1
# singledispatch==3.4.0.3
# six==1.11.0
# snowballstemmer==1.2.1
# sortedcollections==0.6.1
# sortedcontainers==1.5.10
# Sphinx==1.7.4
# sphinxcontrib-websupport==1.0.1
# spyder==3.2.8
# SQLAlchemy==1.2.7
# statsmodels==0.9.0
# sympy==1.1.1
# tables==3.4.3
# tblib==1.3.2
# terminado==0.8.1
# testpath==0.3.1
# toolz==0.9.0
# tornado==5.0.2
# traitlets==4.3.2
# typing==3.6.4
# unicodecsv==0.14.1
# urllib3==1.22
# wcwidth==0.1.7
# webencodings==0.5.1
# Werkzeug==0.14.1
# widgetsnbextension==3.2.1
# win-inet-pton==1.0.1
# win-unicode-console==0.5
# wincertstore==0.2
# wrapt==1.10.11
# xlrd==1.1.0
# XlsxWriter==1.0.2
# xlwings==0.11.8
# xlwt==1.3.0
# zict==0.1.3
# You are using pip version 10.0.1, however version 20.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !pip install moviepy --user
# Out:
# Collecting moviepy
# Requirement already satisfied: numpy in c:\users\isimr\appdata\roaming\python\python36\site-packages (from moviepy) (1.17.0)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in c:\users\isimr\appdata\roaming\python\python36\site-packages (from moviepy) (4.3.0)
# Collecting imageio-ffmpeg>=0.2.0; python_version >= "3.4" (from moviepy)
#   Using cached https://files.pythonhosted.org/packages/2c/af/f04cd614c5125a1b2d47324ec0f16fdae3abe1df5bacc4f4d80db7b679c1/imageio_ffmpeg-0.3.0-py3-none-win_amd64.whl
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\program files (x86)\microsoft visual studio\shared\anaconda3_64\lib\site-packages (from moviepy) (2.18.4)
# Collecting tqdm<5.0,>=4.11.2 (from moviepy)
#   Using cached https://files.pythonhosted.org/packages/cc/2e/4307206db63f05ed37e21d4c0d843d0fbcacd62479f8ce99ba0f2c0875e0/tqdm-4.42.0-py2.py3-none-any.whl
# Collecting imageio<3.0,>=2.5; python_version >= "3.4" (from moviepy)
#   Using cached https://files.pythonhosted.org/packages/1a/de/f7f985018f462ceeffada7f6e609919fbcc934acd9301929cba14bc2c24a/imageio-2.6.1-py3-none-any.whl
# Collecting proglog<=1.0.0 (from moviepy)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\program files (x86)\microsoft visual studio\shared\anaconda3_64\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\program files (x86)\microsoft visual studio\shared\anaconda3_64\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\program files (x86)\microsoft visual studio\shared\anaconda3_64\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files (x86)\microsoft visual studio\shared\anaconda3_64\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2018.4.16)
# Requirement already satisfied: pillow in c:\program files (x86)\microsoft visual studio\shared\anaconda3_64\lib\site-packages (from imageio<3.0,>=2.5; python_version >= "3.4"->moviepy) (5.1.0)
# Installing collected packages: imageio-ffmpeg, tqdm, imageio, proglog, moviepy
# Successfully installed imageio-2.6.1 imageio-ffmpeg-0.3.0 moviepy-1.0.1 proglog-0.1.9 tqdm-4.42.0
# You are using pip version 10.0.1, however version 20.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import moviepy

# %%
# !pip3 freeze
# Out:
# altgraph==0.16.1
# backcall==0.1.0
# certifi==2019.6.16
# chardet==3.0.4
# colorama==0.3.9
# cycler==0.10.0
# decorator==4.3.0
# future==0.17.1
# idna==2.8
# imageio==2.6.1
# imageio-ffmpeg==0.3.0
# ipython==6.5.0
# ipython-genutils==0.2.0
# jedi==0.12.1
# kiwisolver==1.0.1
# line-profiler==2.1.2
# lxml==4.4.0
# macholib==1.11
# matplotlib==3.1.2
# memory-profiler==0.54.0
# mlxtend==0.14.0
# moviepy==1.0.1
# msgpack==0.6.2
# numpy==1.17.0
# panda==0.3.1
# pandas==0.25.0
# pandas-datapackage-reader==0.12.1
# pandas-datareader==0.7.4
# parso==0.3.1
# patsy==0.5.1
# pefile==2019.4.18
# pickleshare==0.7.4
# Pillow==7.0.0
# proglog==0.1.9
# prompt-toolkit==1.0.15
# psutil==5.4.7
# Pygments==2.2.0
# PyInstaller==3.4
# pyparsing==2.3.1
# python-dateutil==2.8.0
# pytz==2018.9
# pywin32-ctypes==0.2.0
# requests==2.22.0
# scikit-learn==0.20.0
# scipy==1.3.1
# seaborn==0.9.0
# simplegeneric==0.8.1
# six==1.11.0
# statsmodels==0.11.0
# style==1.1.0
# tqdm==4.42.0
# traitlets==4.3.2
# update==0.0.1
# urllib3==1.25.3
# wcwidth==0.1.7
# wrapt==1.11.2
# XlsxWriter==1.0.2
