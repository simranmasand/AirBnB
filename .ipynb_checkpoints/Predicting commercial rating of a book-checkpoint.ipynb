# %%
import requests

url_starter ='https://api.nytimes.com/svc/books/v3'
api_key='XDaanlO4mcoiaIho3lgNNpm8F1ALBNtV'
#structure --> https://api.nytimes.com/svc/books/v3/lists/current/hardcover-fiction.json?api-key=yourkey
list_names= '/lists/names.json?api-key='
list_history = '/lists/best-sellers/2012-09-08/hardcover-fiction.json?api-key='

nytimes_data = requests.get(url_starter+list_history+api_key)

# %%
nytimes_data.json()
import pandas as pd
import json
import ast

# %%
nytimes_json =nytimes_data.text
pd.read_json(nytimes_json)
# Out:
#    status                                          copyright  num_results  \
# 0      OK  Copyright (c) 2020 The New York Times Company....        32586
# 1      OK  Copyright (c) 2020 The New York Times Company....        32586
# 2      OK  Copyright (c) 2020 The New York Times Company....        32586
# 3      OK  Copyright (c) 2020 The New York Times Company....        32586
# 4      OK  Copyright (c) 2020 The New York Times Company....        32586
# 5      OK  Copyright (c) 2020 The New York Times Company....        32586
# 6      OK  Copyright (c) 2020 The New York Times Company....        32586
# 7      OK  Copyright (c) 2020 The New York Times Company....        32586
# 8      OK  Copyright (c) 2020 The New York Times Company....        32586
# 9      OK  Copyright (c) 2020 The New York Times Company....        32586
# 10     OK  Copyright (c) 2020 The New York Times Company....        32586
# 11     OK  Copyright (c) 2020 The New York Times Company....        32586
# 12     OK  Copyright (c) 2020 The New York Times Company....        32586
# 13     OK  Copyright (c) 2020 The New York Times Company....        32586
# 14     OK  Copyright (c) 2020 The New York Times Company....        32586
# 15     OK  Copyright (c) 2020 The New York Times Company....        32586
# 16     OK  Copyright (c) 2020 The New York Times Company....        32586
# 17     OK  Copyright (c) 2020 The New York Times Company....        32586
# 18     OK  Copyright (c) 2020 The New York Times Company....        32586
# 19     OK  Copyright (c) 2020 The New York Times Company....        32586
#
#                                               results
# 0   {'title': '"I GIVE YOU MY BODY ..."', 'descrip...
# 1   {'title': '"MOST BLESSED OF THE PATRIARCHS"', ...
# 2   {'title': '#ASKGARYVEE', 'description': 'The e...
# 3   {'title': '#GIRLBOSS', 'description': 'An onli...
# 4   {'title': '#IMOMSOHARD', 'description': '', 'c...
# 5   {'title': '#NEVERAGAIN', 'description': 'Stude...
# 6   {'title': '$100 STARTUP', 'description': 'How ...
# 7   {'title': '$20 PER GALLON', 'description': '',...
# 8   {'title': ''57, Chicago', 'description': None,...
# 9   {'title': ''ROCK OF AGES: ''ROLLING STONE'' HI...
# 10  {'title': ''THE HIGH ROAD TO CHINA: GEORGE BOG...
# 11  {'title': ''TIL DEATH', 'description': '', 'co...
# 12  {'title': ''TIL DEATH DO US PART', 'descriptio...
# 13  {'title': ''Til Faith Do Us Part: How Interfai...
# 14  {'title': ''TIS THE SEASON', 'description': 'T...
# 15  {'title': '------, THAT'S DELICIOUS', 'descrip...
# 16  {'title': '...and the Horse He Rode In On: The...
# 17  {'title': '.HACK G.U.   , VOL. 5', 'descriptio...
# 18  {'title': '1 Ragged Ridge Road', 'description'...
# 19  {'title': '1,000 PLACES TO SEE BEFORE YOU DIE'...
